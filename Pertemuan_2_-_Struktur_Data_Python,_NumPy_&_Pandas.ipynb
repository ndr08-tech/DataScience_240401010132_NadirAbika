# %% [markdown]
# # Pertemuan 2 - Struktur Data Python, NumPy & Pandas
#
# **Nama:** Nadir Abika
# **NIM:** 240401010132
# **Kelas:** IF403

# %%
print("PERTEMUAN 2 - STRUKTUR DATA PYTHON, NUMPY & PANDAS")
print()

print("Ringkasan Materi")
print("1. Struktur Data Python")
print("- List: mutable dan berurutan")
print("- Tuple: immutable dan berurutan")
print("- Dictionary: pasangan key-value")
print("- Set: kumpulan data unik")
print()

print("2. NumPy")
print("NumPy digunakan untuk komputasi numerik dengan ndarray.")
print("NumPy lebih cepat dibanding list Python.")
print()

print("3. Pandas")
print("Pandas digunakan untuk manipulasi dan analisis data.")
print("Struktur utama Pandas adalah Series dan DataFrame.")
print()

print("4. Analisis Data")
print("Pandas menyediakan filtering, seleksi data, dan groupby.")
# Out:
# PERTEMUAN 2 - STRUKTUR DATA PYTHON, NUMPY & PANDAS
#
# Ringkasan Materi
# 1. Struktur Data Python
# - List: mutable dan berurutan
# - Tuple: immutable dan berurutan
# - Dictionary: pasangan key-value
# - Set: kumpulan data unik
#
# 2. NumPy
# NumPy digunakan untuk komputasi numerik dengan ndarray.
# NumPy lebih cepat dibanding list Python.
#
# 3. Pandas
# Pandas digunakan untuk manipulasi dan analisis data.
# Struktur utama Pandas adalah Series dan DataFrame.
#
# 4. Analisis Data
# Pandas menyediakan filtering, seleksi data, dan groupby.

# %%
# List
data = [10, 20, 30]
data.append(40)
print("List:", data)

# NumPy
import numpy as np

arr = np.array([1, 2, 3, 4, 5])
print("Mean:", np.mean(arr))

# Pandas
import pandas as pd

df = pd.DataFrame({
    "Nama": ["Ali", "Budi", "Caca"],
    "Usia": [22, 25, 21]
})

print(df)
# Out:
# List: [10, 20, 30, 40]
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 7
#       3 data.append(40)
#       4 print("List:", data)
#       5
#       6 # NumPy
# ----> 7 import numpy as np
#       8
#       9 arr = np.array([1, 2, 3, 4, 5])
#      10 print("Mean:", np.mean(arr))
#
# ModuleNotFoundError: No module named 'numpy'

# %% [markdown]
# # Kesimpulan
#
# Pada pertemuan ini saya mempelajari struktur data Python (List, Tuple, Dictionary, dan Set), penggunaan NumPy untuk komputasi numerik, serta Pandas untuk manipulasi dan analisis data.
#
# **Temuan utama:**
# - NumPy lebih efisien untuk pengolahan data numerik.
# - Pandas mempermudah pengelolaan data dalam bentuk tabel.
# - Filtering dan groupby sangat membantu dalam analisis data.
#
# **Keterbatasan/Pertanyaan:**
# - Belum mempelajari visualisasi data.
# - Perlu latihan lebih lanjut menggunakan dataset yang lebih besar dan kompleks.
