# %% [markdown]
# ## Pertemuan 1 - Pengenalan Data Science
#
# **Nama:** Nadir Abika
# **NIM:** 240401010132
# **Kelas:** IF403
# **Mata Kuliah:** Data Science

# %%
Ringkasan Materi

Pada pertemuan pertama, saya mempelajari konsep dasar Data Science sebagai bidang multidisiplin yang menggabungkan statistika, ilmu komputer, dan pengetahuan domain untuk menghasilkan informasi yang bermanfaat dari data. Data Science berperan penting dalam membantu pengambilan keputusan melalui proses pengumpulan, pengolahan, analisis, dan interpretasi data.

Materi yang dipelajari mencakup tiga pilar utama Data Science, yaitu Statistika dan Matematika, Ilmu Komputer, serta Domain Knowledge. Ketiga pilar tersebut saling melengkapi dalam proses analisis data dan penyelesaian masalah di berbagai bidang. Selain itu, dipelajari juga konsep Big Data yang terdiri dari Volume, Velocity, Variety, dan Veracity.

Pada pertemuan ini saya juga mengenal berbagai profesi di bidang Data Science, seperti Data Analyst, Data Scientist, Machine Learning Engineer, dan Data Engineer. Selanjutnya dipelajari metodologi CRISP-DM yang terdiri dari enam tahapan, yaitu Business Understanding, Data Understanding, Data Preparation, Modeling, Evaluation, dan Deployment sebagai kerangka kerja dalam proyek Data Science.

Selain materi teori, saya mempelajari penggunaan Google Colab, Jupyter Notebook, GitHub, serta dasar-dasar pemrograman Python seperti variabel, tipe data, list, perulangan, dan fungsi sederhana.
# Out:
#   Cell In[1], line 1
#     Ringkasan Materi
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Kesimpulan
#
# Pada pertemuan pertama saya memahami pengertian Data Science, ruang lingkupnya, serta pentingnya data dalam mendukung pengambilan keputusan. Saya mempelajari tiga pilar utama Data Science, konsep Big Data, berbagai profesi di bidang Data Science, serta metodologi CRISP-DM yang digunakan dalam pengembangan proyek data.
#
# Melalui praktikum, saya memperoleh pengalaman menggunakan Google Colab, Jupyter Notebook, GitHub, dan Python sebagai dasar pembelajaran Data Science. Materi ini memberikan pemahaman awal mengenai proses kerja seorang praktisi Data Science dan menjadi fondasi untuk mempelajari teknik analisis data yang lebih lanjut pada pertemuan berikutnya.
#
# **Temuan Utama:** Data Science merupakan kombinasi antara kemampuan analisis, pemrograman, dan pemahaman terhadap permasalahan pada suatu bidang.
#
# **Keterbatasan/Pertanyaan:** Materi masih bersifat pengenalan sehingga belum membahas teknik analisis data dan machine learning secara mendalam. Saya ingin mempelajari lebih lanjut penerapan Data Science dalam menyelesaikan permasalahan nyata menggunakan data.
