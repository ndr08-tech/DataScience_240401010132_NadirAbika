# %%
# Data Science - Pertemuan 1
## Pengenalan Data Science

print("Nama: Nadir Abika")
print("NIM: 240401010132")
print("Kelas: IF403")

# %%
## Tujuan Praktikum

Mempelajari konsep dasar Data Science, siklus CRISP-DM, serta tools yang digunakan dalam praktikum Data Science.

# %%
## Ringkasan Materi

### 1. Apa itu Data Science?

Data Science adalah bidang yang menggabungkan statistik, pemrograman, dan pengetahuan domain untuk mengolah data menjadi informasi yang berguna dalam pengambilan keputusan.

### 2. Tiga Pilar Utama Data Science

- Matematika dan Statistik
- Pemrograman/Computer Science
- Domain Knowledge (pengetahuan bidang)

### 3. Siklus CRISP-DM

CRISP-DM terdiri dari enam tahapan:

1. Business Understanding
2. Data Understanding
3. Data Preparation
4. Modeling
5. Evaluation
6. Deployment

### 4. Tools Data Science

- Python
- Google Colab
- Jupyter Notebook
- GitHub

# %%
## Praktik Python Sederhana
print("Hello Data Science")

data_science_tools = [
    "Python",
    "Google Colab",
    "Jupyter Notebook",
    "GitHub"
]

for tool in data_science_tools:
    print(tool)
	
Hello Data Science
Python
Google Colab
Jupyter Notebook
GitHub

# %%
# Kesimpulan

print("Pada pertemuan pertama saya mempelajari pengertian Data Science, tiga pilar utama Data Science, siklus CRISP-DM, serta tools yang digunakan selama perkuliahan.")

### Temuan Utama
- Data Science membantu pengambilan keputusan berbasis data.
- CRISP-DM merupakan kerangka kerja umum dalam proyek Data Science.
- Python menjadi bahasa utama dalam praktikum.

### Keterbatasan / Pertanyaan
- Belum mempelajari implementasi setiap tahap CRISP-DM secara mendalam.
- Perlu memahami penggunaan dataset nyata pada proyek Data Science.
